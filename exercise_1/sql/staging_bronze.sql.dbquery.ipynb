-- %%
--creating the top level catalog 
CREATE CATALOG IF NOT EXISTS retail_demo;
USE CATALOG retail_demo;

--create bronze layer of medallion
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE VOLUME IF NOT EXISTS bronze.landing;

CREATE OR REFRESH STREAMING TABLE bronze.orders
 order_id STRING
 order_date STRING
